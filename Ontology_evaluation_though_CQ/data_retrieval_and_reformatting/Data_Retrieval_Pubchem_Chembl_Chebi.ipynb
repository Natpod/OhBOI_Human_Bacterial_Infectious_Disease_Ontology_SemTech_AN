# %% [markdown]
# # Data retrieval PubCHEM and ChEMBL REST programatic access
#
#
#
# ---
# Author : *Natalia García Sánchez, Ana Solbas

# %% [markdown]
# # INDEX
# 1. PubCHEM programatic access -> [Pubchem section](#Pubchem)
# 2. ChEMBL programatic access -> [ChEMBL section](#ChEMBL)
# 3. Conclusion -> [Conclusion](#Conclusion)

# %% [markdown]
# ### Importing libraries

# %%
# libraries
import json  # lets us work with the json format
import requests  # allows Python to make web requests
import pandas as pd # analysis of tabular data
from pandas import json_normalize
import numpy as np # numerical library
from IPython.display import Image # Public API for display tools in IPython.

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/biostruct/pubchem.xlsx')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
p_chemlist = df.PubChem_label.tolist()

# %% [markdown]
# <a id='#Pubchem'></a>

# %% [markdown]
# ## 1. PubCHEM programatic access
#
# * Searching for Canonical SMILES
# * Doing a 2D similarity analysis with ibuprofen SMILES

# %%
BASE_URL1 = "https://pubchem.ncbi.nlm.nih.gov/rest/pug"
smileslist = []
for p_chemname in p_chemlist:

  url1 = BASE_URL1+ f"/compound/name/{p_chemname}/property/CanonicalSMILES/JSON"

  r1 = requests.get(url1)
  response = r1.json()

  if "PropertyTable" in response:
      SMILES = response["PropertyTable"]["Properties"][0]["CanonicalSMILES"];
      smileslist.append(SMILES)
  else:
      print(f"Could not find matches for PubChem name: {p_chemname}")
# Out:
# Could not find matches for PubChem name: cephem
# Could not find matches for PubChem name: CAS 1405-87-4

# %%
df = df[df['PubChem_label'] != 'cephem']
df = df[df['PubChem_label'] != 'CAS 1405-87-4']

# %%
df['SMILES'] = smileslist

# %%
print("Canonical SMILES for ibuprofen is : ", SMILES)
# Out:
# Canonical SMILES for ibuprofen is :  CC(C)CC1=CC=C(C=C1)C(C)C(=O)O

# %%
url2 = BASE_URL1 +f"/compound/fastsimilarity_2d/smiles/cids/JSON?Threshold=80"
r2 = requests.post(url2, data={'smiles' : SMILES})
cids_simmolPub = r2.json()

print("# Number of CIDs:", len(cids_simmolPub['IdentifierList']['CID']))
print(sorted(cids_simmolPub['IdentifierList']['CID']))
# Out:
# # Number of CIDs: 108825
# [107, 997, 999, 1303, 1542, 2449, 3332, 3335, 3394, 3395, 3672, 3825, 3848, 3858, 3965, 4127, 4702, 4775, 5127, 5258, 6463, 6730, 6862, 7012, 7403, 7418, 7458, 7470, 7489, 7559, 7590, 7600, 7601, 7643, 7655, 7658, 7709, 8333, 8373, 8767, 8792, 9024, 9837, 9978, 10194, 10296, 10356, 10714, 10726, 10820, 11393, 11470, 11782, 11892, 11897, 11915, 12031, 12073, 12086, 12121, 12439, 13084, 13222, 13234, 13737, 13890, 14098, 14103, 14144, 14583, 14695, 15071, 15093, 15250, 15618, 15717, 15858, 15879, 15880, 15890, 16046, 16197, 16237, 16757, 17099, 17124, 17314, 17452, 18663, 18744, 18960, 19024, 19147, 19570, 19986, 20202, 20233, 20288, 20447, 20724, 21101, 21106, 21235, 21717, 21880, 21881, 21882, 22220, 22642, 22810, 23042, 23269, 23739, 24123, 24371, 24915, 25239, 25685, 25932, 26403, 26436, 27266, 27877, 29039, 29759, 29788, 30314, 30725, 30801, 30931, 30938, 31102, 31210, 31722, 32153, 32282, 32601, 33479, 33654, 34170, 34656, 34658, 34872, 34882, 37589, 37791, 37846, 37847, 38002, 38111, 38719, 39912, 40045, 40387, 41122, 41519, 41643, 41911, 41912, 42280, 42368, 42864, 42949, 43524, 47801, 47806, 47946, 48186, 48187, 48190, 49343, 49344, 50233, 52416, 53169, 53379, 53381, 53382, 53385, 56273, 56572, 56573, 57472, 58097, 59041, 59083, 60998, 61000, 61050, 61379, 61384, 61446, 61452, 61521, 62469, 62553, 62578, 62796, 62821, 64798, 64800, 64862, 64920, 65287, 66167, 66450, 66514, 66551, 66677, 66724, 67148, 67617, 67695, 67979, 68114, 68524, 68756, 68769, 68776, 68823, 68941, 68992, 69090, 69147, 69519, 69571, 69732, 70032, 70323, 70515, 70817, 71170, 71526, 71703, 72099, 72133, 72158, 73716, 73914, 73927, 74185, 74220, 74379, 74492, 74541, 74653, 74654, 74809, 75534, 75791, 76863, 76990, 77019, 77181, 77814, 77815, 77816, 77823, 77902, 77926, 78123, 78192, 78213, 78230, 78279, 79546, 79552, 79587, 79594, 79676, 79695, 80206, 80406, 80585, 80634, 81568, 81607, 81760, 81964, 81984, 81990, 82349, 82704, 83615, 84175, 84176, 84261, 84403, 84848, 85037, 85291, 85339, 85688, 85728, 86020, 87136, 87161, 87754, 87755, 88219, 88337, 88631, 88637, 88710, 89196, 89233, 89317, 89651, 89740, 90265, 91332, 92043, 92337, 93761, 93896, 94391, 94852, 94885, 94919, 95205, 95298, 95325, 95376, 95389, 95459, 95511, 95517, 95557, 95615, 95918, 96145, 96207, 96214, 96293, 96325, 96468, 96501, 96528, 96574, 96732, 96783, 97700, 97713, 97795, 97919, 97942, 98004, 98014, 98071, 98127, 98283, 98359, 98421, 98492, 98549, 98622, 98639, 98664, 98950, 99094, 99643, 99796, 99862, 100245, 101023, 101104, 101154, 101234, 101315, 101370, 102525, 102526, 102567, 102641, 102649, 102780, 103006, 104051, 104069, 105595, 106694, 106738, 106936, 107334, 108455, 108885, 109101, 109338, 109553, 109639, 110189, 110190, 110191, 110729, 112035, 112192, 112290, 112291, 112450, 112733, 113867, 114492, 114864, 115681, 117055, 117056, 117352, 117814, 117857, 118146, 118251, 118286, 118342, 118343, 118616, 119352, 119694, 119711, 119801, 119850, 120107, 120802, 122418, 122752, 123581, 123585, 123587, 123810, 124534, 125557, 125870, 125874, 126163, 127414, 127415, 127633, 128573, 128588, 128642, 129502, 129678, 130854, 132836, 132877, 133629, 133630, 133762, 135062, 135131, 135390, 136170, 136302, 136429, 136696, 136849, 136850, 136911, 137197, 137214, 137384, 137589, 137601, 137629, 137945, 138042, 138064, 138520, 138552, 138729, 138883, 139037, 139049, 140324, 140620, 140723, 140724, 141012, 141089, 141090, 141456, 141739, 142104, 143182, 143498, 145424, 148259, 148588, 150866, 151102, 151451, 151922, 155474, 155520, 155690, 155954, 156356, 156701, 157136, 158013, 158270, 158312, 158313, 158632, 161684, 161862, 162730, 163312, 164321, 166175, 167544, 167853, 168275, 168307, 168576, 168658, 168791, 170036, 170486, 171526, 172977, 173910, 174983, 175127, 175460, 177018, 177955, 179135, 179137, 179446, 179508, 180540, 180643, 180926, 180927, 181888, 182253, 182443, 182473, 183963, 184253, 184254, 184255, 185073, 185074, 185681, 185912, 187283, 188523, 188529, 188531, 191326, 1 ...

# %% [markdown]
# <a id='#ChEMBL'></a>

# %% [markdown]
# ## 2. ChEMBL programatic access
#
# * Searching for Canonical SMILES
# * Doing a 2D similarity analysis with ibuprofen SMILES

# %%
BASE_URL2 = "https://www.ebi.ac.uk/chembl/api/data/"

# %%
df
# Out:
#                                            PubChem_ID    PubChem_label  \
# 0   https://pubchem.ncbi.nlm.nih.gov/compound/1000...    spectinomycin
# 1   https://pubchem.ncbi.nlm.nih.gov/compound/1000...      amoxicillin
# 2   https://pubchem.ncbi.nlm.nih.gov/compound/1000...        monomycin
# 3   https://pubchem.ncbi.nlm.nih.gov/compound/1000...     azithromycin
# 4   https://pubchem.ncbi.nlm.nih.gov/compound/1000...      clindamycin
# ..                                                ...              ...
# 84  https://pubchem.ncbi.nlm.nih.gov/compound/1064...        delamanid
# 85  https://pubchem.ncbi.nlm.nih.gov/compound/1258...     tetracycline
# 86  https://pubchem.ncbi.nlm.nih.gov/compound/1441...  oxytetracycline
# 87  https://pubchem.ncbi.nlm.nih.gov/compound/1000...    pentobarbital
# 88  https://pubchem.ncbi.nlm.nih.gov/compound/1000...    phenobarbital
#
#                                                SMILES
# 0        CC1CC(=O)C2(C(O1)OC3C(C(C(C(C3O2)NC)O)NC)O)O
# 1   CC1(C(N2C(S1)C(C2=O)NC(=O)C(C3=CC=C(C=C3)O)N)C...
# 2   C1C(C(C(C(C1N)OC2C(C(C(C(O2)CO)O)O)N)OC3C(C(C(...
# 3   CCC1C(C(C(N(CC(CC(C(C(C(C(C(=O)O1)C)OC2CC(C(C(...
# 4   CCCC1CC(N(C1)C)C(=O)NC(C2C(C(C(C(O2)SC)O)O)O)C...
# ..                                                ...
# 84  CC1(CN2C=C(N=C2O1)[N+](=O)[O-])COC3=CC=C(C=C3)...
# 85  CC1(C2CC3C(C(=O)C(=C(C3(C(=O)C2=C(C4=C1C=CC=C4...
# 86  CC1(C2C(C3C(C(=O)C(=C(C3(C(=O)C2=C(C4=C1C=CC=C...
# 87                      CCCC(C)C1(C(=O)NC(=O)NC1=O)CC
# 88                  CCC1(C(=O)NC(=O)NC1=O)C2=CC=CC=C2
#
# [87 rows x 3 columns]

# %%
specsmileslist = df.SMILES.tolist()
nosmileslist = []
chemblidlist=[]
formulalist=[]
weightlist=[]
chebiidlist=[]
atclist=[]
for specsmiles in specsmileslist:
  #uses previous SMILES for the search
  tanimoto_url = BASE_URL2 + f"similarity/{specsmiles}/100"
  r3 = requests.get(tanimoto_url, headers={"Accept":"application/json"}).json()
  if len(r3['molecules'])>0:
    propretrieved = list(r3['molecules'][0].keys())
    if 'molecule_chembl_id' in propretrieved and 'molecule_properties' in propretrieved and 'atc_classifications' in propretrieved and 'chebi_par_id'in propretrieved:
      cids_simmolCh = pd.DataFrame.from_dict(r3['molecules'])[['molecule_chembl_id', 'chebi_par_id', 'atc_classifications']]
      chemblidlist.append(cids_simmolCh['molecule_chembl_id'][0])
      chebiidlist.append(cids_simmolCh['chebi_par_id'][0])
      atclist.append([cids_simmolCh['atc_classifications'][0]])
      dictprop = r3['molecules'][0]['molecule_properties']

      formulalist.append(dictprop['full_molformula'])
      weightlist.append(dictprop['full_mwt'])
      print("Number of ChEMBL IDs found : ", cids_simmolCh.shape[0] )
    else:
        print(f"Could not find matches for PubChem name: {specsmiles}")
        nosmileslist.append(specsmiles)
  else:
      print(f"Could not find matches for PubChem name: {specsmiles}")
      nosmileslist.append(specsmiles)
  chemblidlist
# Out:
# Number of ChEMBL IDs found :  10
# Number of ChEMBL IDs found :  4
# Number of ChEMBL IDs found :  11
# Number of ChEMBL IDs found :  6
# Number of ChEMBL IDs found :  8
# Number of ChEMBL IDs found :  7
# Number of ChEMBL IDs found :  15
# Number of ChEMBL IDs found :  3
# Number of ChEMBL IDs found :  2
# Number of ChEMBL IDs found :  12
# Number of ChEMBL IDs found :  8
# Number of ChEMBL IDs found :  6
# Number of ChEMBL IDs found :  15
# Number of ChEMBL IDs found :  5
# Number of ChEMBL IDs found :  5
# Number of ChEMBL IDs found :  2
# Number of ChEMBL IDs found :  5
# Number of ChEMBL IDs found :  2
# Number of ChEMBL IDs found :  1
# Number of ChEMBL IDs found :  5
# Number of ChEMBL IDs found :  7
# Number of ChEMBL IDs found :  1
# Number of ChEMBL IDs found :  1
# Number of ChEMBL IDs found :  6
# Number of ChEMBL IDs found :  5
# Number of ChEMBL IDs found :  2
# Number of ChEMBL IDs found :  10
# Number of ChEMBL IDs found :  8
# Number of ChEMBL IDs found :  4
# Number of ChEMBL IDs found :  5
# Number of ChEMBL IDs found :  10
# Number of ChEMBL IDs found :  6
# Number of ChEMBL IDs found :  4
# Number of ChEMBL IDs found :  17
# Number of ChEMBL IDs found :  3
# Number of ChEMBL IDs found :  6
# Number of ChEMBL IDs found :  5
# Number of ChEMBL IDs found :  5
# Number of ChEMBL IDs found :  4
# Number of ChEMBL IDs found :  9
# Number of ChEMBL IDs found :  4
# Number of ChEMBL IDs found :  2
# Number of ChEMBL IDs found :  7
# Number of ChEMBL IDs found :  20
# Number of ChEMBL IDs found :  7
# Number of ChEMBL IDs found :  3
# Number of ChEMBL IDs found :  6
# Number of ChEMBL IDs found :  4
# Number of ChEMBL IDs found :  6
# Number of ChEMBL IDs found :  2
# Number of ChEMBL IDs found :  13
# Number of ChEMBL IDs found :  3
# Number of ChEMBL IDs found :  6
# Number of ChEMBL IDs found :  2
# Number of ChEMBL IDs found :  2
# Number of ChEMBL IDs found :  3
# Number of ChEMBL IDs found :  12
# Number of ChEMBL IDs found :  1
# Number of ChEMBL IDs found :  5
# Number of ChEMBL IDs found :  4
# Number of ChEMBL IDs found :  8
# Number of ChEMBL IDs found :  9
# Number of ChEMBL IDs found :  11
# Number of ChEMBL IDs found :  3
# Number of ChEMBL IDs found :  4
# Number of ChEMBL IDs found :  6
# Number of ChEMBL IDs found :  5
# Number of ChEMBL IDs found :  4
# Number of ChEMBL IDs found :  2
# Number of ChEMBL IDs found :  6
# Number of ChEMBL IDs found :  11
# Number of ChEMBL IDs found :  7
# Number of ChEMBL IDs found :  2
# Number of ChEMBL IDs found :  2
# Number of ChEMBL IDs found :  2
# Number of ChEMBL IDs found :  3

# %%
df = df[~df['SMILES'].isin(nosmileslist)]
df['ChEMBL_ID'] = chemblidlist
df['CHEBI_ID'] = chebiidlist
df['formula'] = formulalist
df['mass'] = weightlist
df['atcClassification'] = atclist

# %%
df
# Out:
#                                            PubChem_ID    PubChem_label  \
# 0   https://pubchem.ncbi.nlm.nih.gov/compound/1000...    spectinomycin
# 1   https://pubchem.ncbi.nlm.nih.gov/compound/1000...      amoxicillin
# 2   https://pubchem.ncbi.nlm.nih.gov/compound/1000...        monomycin
# 3   https://pubchem.ncbi.nlm.nih.gov/compound/1000...     azithromycin
# 4   https://pubchem.ncbi.nlm.nih.gov/compound/1000...      clindamycin
# ..                                                ...              ...
# 83  https://pubchem.ncbi.nlm.nih.gov/compound/1000...             APAs
# 84  https://pubchem.ncbi.nlm.nih.gov/compound/1064...        delamanid
# 86  https://pubchem.ncbi.nlm.nih.gov/compound/1441...  oxytetracycline
# 87  https://pubchem.ncbi.nlm.nih.gov/compound/1000...    pentobarbital
# 88  https://pubchem.ncbi.nlm.nih.gov/compound/1000...    phenobarbital
#
#                                                SMILES      ChEMBL_ID  \
# 0        CC1CC(=O)C2(C(O1)OC3C(C(C(C(C3O2)NC)O)NC)O)O  CHEMBL4543601
# 1   CC1(C(N2C(S1)C(C2=O)NC(=O)C(C3=CC=C(C=C3)O)N)C...  CHEMBL2105950
# 2   C1C(C(C(C(C1N)OC2C(C(C(C(O2)CO)O)O)N)OC3C(C(C(...  CHEMBL4303788
# 3   CCC1C(C(C(N(CC(CC(C(C(C(C(C(=O)O1)C)OC2CC(C(C(...  CHEMBL2361091
# 4   CCCC1CC(N(C1)C)C(=O)NC(C2C(C(C(C(O2)SC)O)O)O)C...  CHEMBL1490142
# ..                                                ...            ...
# 83                            C1=CC(=C(C=C1N)O)C(=O)O     CHEMBL1169
# 84  CC1(CN2C=C(N=C2O1)[N+](=O)[O-])COC3=CC=C(C=C3)...  CHEMBL3188499
# 86  CC1(C2C(C3C(C(=O)C(=C(C3(C(=O)C2=C(C4=C1C=CC=C...  CHEMBL4591469
# 87                      CCCC(C)C1(C(=O)NC(=O)NC1=O)CC      CHEMBL971
# 88                  CCC1(C(=O)NC(=O)NC1=O)C2=CC=CC=C2       CHEMBL40
#
#     CHEBI_ID         formula    mass atcClassification
# 0        NaN  C14H33Cl3N2O10  495.78              [[]]
# 1    51255.0   C16H18N3NaO5S  387.39              [[]]
# 2        NaN     C23H45N5O14  615.63              [[]]
# 3        NaN     C38H72N2O12  749.00              [[]]
# 4        NaN  C18H36Cl2N2O6S  479.47              [[]]
# ..       ...             ...     ...               ...
# 83   27565.0         C7H7NO3  153.14       [[J04AA01]]
# 84       NaN    C25H25F3N4O6  534.49              [[]]
# 86       NaN    C22H25ClN2O9  496.90              [[]]
# 87    7984.0    C11H17N2NaO3  248.26              [[]]
# 88    8069.0      C12H12N2O3  232.24       [[N03AA02]]
#
# [76 rows x 8 columns]

# %%
df.to_csv('pubchem_chembl_chebi.csv', index=False)

# %% [markdown]
# <a id='#Conclusion'></a>
