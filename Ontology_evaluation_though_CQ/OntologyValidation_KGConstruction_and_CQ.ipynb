# %% [markdown]
# # Ontology Validation: Competency Question addressing through Knowledge Graph Construction and Access on biomedical, pharmacological and biological  heterogeneous data sources
# ---
#
# ***Authors*** : *Ana Solbas, Natalia García Sánchez*
#
# **Date** : *21/01/2023*
#
# ***Description***: Knowledge Graph (KG) materialization, description and access on biomedical, pharmacological and biological  heterogeneous data sources using Morph-KGC previous mapping file in RML
#
# v1.0
#
# *Dependencies*: `morph-kgc`
#
# ---

# %% [markdown]
# ## KG generation
# This will be done with the `morph-kgc` python library

# %% [markdown]
# **[Morph-KGC](https://github.com/oeg-upm/morph-kgc)** is an engine that constructs our wanted **[RDF](https://www.w3.org/TR/rdf11-concepts/)** knowledge graphs from heterogeneous data sources with different mapping language, among which the **[RML](https://rml.io/specs/rml/)** language can be found. This document will have the declarative mapping instructions we previously specified in our **[YARRRML](https://rml.io/yarrrml/)** document, and is obtained through prior conversion using the **[YARRRML's Matey](https://rml.io/yarrrml/assets/pdf/eswc2018.pdf)**  browser-based application that helps you write YARRRML rules and generate the corresponding final RML mapping files. All the mentioned files are annexed in the Supplementary Material Files.
#
# Morph-KGC currently supports our data sources format **CSV** the working directory of this Colab Script for running the mapping.
#
# We will run this library via the **command line**.This is the most recommended option if you work with large volumes of data.

# %% [markdown]
# First of all, we need to **install** [Morph-KGC](https://pypi.org/project/morph-kgc) (this will also install [RDFLib](https://pypi.org/project/rdflib/) and [Oxigraph](https://pypi.org/project/pyoxigraph/)).

# %%
# !pip install morph-kgc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting morph-kgc
#   Downloading morph_kgc-2.3.1-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 KB 1.8 MB/s eta 0:00:00
# Collecting duckdb>=0.5.0
#   Downloading duckdb-0.6.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.4/14.4 MB 47.8 MB/s eta 0:00:00
# Collecting pyoxigraph>=0.3.0
#   Downloading pyoxigraph-0.3.11-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 8.1 MB/s eta 0:00:00
# Collecting sql-metadata>=2.3.0
#   Downloading sql_metadata-2.6.0-py3-none-any.whl (21 kB)
# Collecting rdflib>=6.1.1
#   Downloading rdflib-6.2.0-py3-none-any.whl (500 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.3/500.3 KB 29.7 MB/s eta 0:00:00
# Collecting jsonpath-python>=1.0.5
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Collecting elementpath>=2.4.0
#   Downloading elementpath-3.0.2-py3-none-any.whl (189 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.1/189.1 KB 12.7 MB/s eta 0:00:00
# Collecting falcon>=3.0.0
#   Downloading falcon-3.1.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 64.6 MB/s eta 0:00:00
# Requirement already satisfied: SQLAlchemy>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from morph-kgc) (1.4.46)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from morph-kgc) (1.3.5)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.8/dist-packages (from duckdb>=0.5.0->morph-kgc) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.3.0->morph-kgc) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.3.0->morph-kgc) (2.8.2)
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 KB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from rdflib>=6.1.1->morph-kgc) (57.4.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.8/dist-packages (from rdflib>=6.1.1->morph-kgc) (3.0.9)
# Requirement already satisfied: sqlparse<0.5.0,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from sql-metadata>=2.3.0->morph-kgc) (0.4.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.8/dist-packages (from SQLAlchemy>=1.4.0->morph-kgc) (2.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=1.3.0->morph-kgc) (1.15.0)
# Installing collected packages: sql-metadata, pyoxigraph, jsonpath-python, isodate, falcon, elementpath, duckdb, rdflib, morph-kgc
# Successfully installed duckdb-0.6.1 elementpath-3.0.2 falcon-3.1.1 isodate-0.6.1 jsonpath-python-1.0.6 morph-kgc-2.3.1 pyoxigraph-0.3.11 rdflib-6.2.0 sql-metadata-2.6.0

# %% [markdown]
# We should mount the contents of the drive to access all mapping files and data sources for the KG

# %%
# drive access to csv files and mapping rules in YARRRML - ignore if using script on local
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Now we just need to **import** Morph-KGC and we are ready to go!

# %%
import morph_kgc

# %% [markdown]
# ### RDF file generation
#
# Now we only have to specify a config file describing the path of the RML `mapping_file.rml.ttl`
#
# The config file `config.ini` has the following contents
#
# ```
# [CONFIGURATION]
#              na_values:
#
# [DataSource1]
#              mappings: /path_to_files/RML_MappingFile.rml.ttl
#
# ```
#
# where `output_tsv_joinfix.rml.ttl` represents the mapping files. Additional configuration specifications, like the missing values symbols expected and used, are specified in the `na_values` variable of `[CONFIGURATION]` section of the .ini file

# %% [markdown]
# The config file can be generated the following way:

# %%
# create the config file
# !echo "[CONFIGURATION]" > path_to_files+'config.ini'
# !echo "na_values: " >> path_to_files+'config.ini'
# !echo "[DataSource1]" >> path_to_files+'config.ini'
# !echo "mappings: /path/RML_MappingFile.rml.ttl" >> 'path/config.ini'

# show the config file
# !cat path_to_files+'config.ini'
# Out:
# [CONFIGURATION]
# na_values:
# [DataSource1]
# mappings: /content/drive/MyDrive/entregase master/OhBOI/YARRML_mapping/YARRRML_Mapping_OhBOI/tsv/Mappings.ttl

# %% [markdown]
# Now with the following command, `morph_kgc` will generate a RDF triple file `knowledge_graph.nt` describing the data following the conceptual schema of the ontology, that can subsequently be loaded into a triplestore

# %%
# !python3 -m morph_kgc path_to_files+'config.ini'
# Out:
# INFO | 2023-01-23 12:31:05,031 | 77 mapping rules retrieved.
# INFO | 2023-01-23 12:31:05,081 | Mapping partition with 45 groups generated.
# INFO | 2023-01-23 12:31:05,082 | Maximum number of rules within mapping group: 21.
# INFO | 2023-01-23 12:31:05,085 | Mappings processed in 6.392 seconds.
# INFO | 2023-01-23 12:31:06,405 | Number of triples generated in total: 3943.
# INFO | 2023-01-23 12:31:06,405 | Materialization finished in 1.257 seconds.

# %% [markdown]
# ## RDF triple post-processing
# Loading output file with RDF triples

# %%
with open('/content/knowledge-graph.nt') as f:
  docstring = f.read()

# %% [markdown]
# Replacing "Â" by ""

# %%
docstring = docstring.replace("Â","")

# %% [markdown]
# Writing processed file to drive

# %%
with open(path_to_files+'OhBOI_RDF.nt', 'w') as f:
  f.write(docstring)

# %% [markdown]
# # KG Access
#
# Now we can work with our RDFLib graph: query, navigate or save the graph and more with **[RDFLib](https://rdflib.readthedocs.io)**, which is the reference library to work with RDF in Python. Morph-KGC can also be used to load a KG to RDFLib.
#
# We will investigate about the final generated KG with several SPARQL queries. This will perform as a validation of KG access.
#
# - Number of Distinct subjects
# - Distinct properties
# - Distinct subject property tuples

# %% [markdown]
# **Load Knowledge Graph to [RDFLib](https://rdflib.readthedocs.io)**
# With the generated RDF we could for instance load it to RDFLib (or any triplestore) and pose queries.
#
# The RDFLib graph output was chosen for this. In this way, instead of using a triplestore such as Brazegraph or GraphDB to upload the RDF data, the data was loaded into a RDFLib datastore importing the rdflib python library in conjunction with morph-kgc library. Then, the RDF data from the KG file had to be converted to a RDFLib graph using both of this libraries. These were the previous steps to perform access to the KG using SPARQL queries using RDFLib.

# %% [markdown]
# Example of the data generated

# %%
import rdflib

g = rdflib.Graph()
g.parse(path_to_files+'OhBOI_RDF.nt')

# paying careful attention to the typo in the property schema:adress 
# that the materialized KG loaded because of a misspelling in the mapping rule declaration

q0 = """
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX obo: <http://purl.obolibrary.org/obo/> 
  PREFIX snomedct: <http://purl.bioontology.org/ontology/SNOMEDCT/> 
  PREFIX ncit:  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#> 
  PREFIX sio: <http://semanticscience.org/resource/> 
  PREFIX mesh: <http://purl.bioontology.org/ontology/MESH/> 
  PREFIX wp: <http://vocabularies.wikipathways.org/wp#> 
  PREFIX cco: <http://rdf.ebi.ac.uk/terms/chembl#> 
  PREFIX ohboi: <https://w3id.org/ohboi#> 

SELECT ?cdsubjects (count (DISTINCT ?s) as ?cdsubjects) 
         WHERE {
           # ?s ?p ?o .}
      """

q0_res = g.query(q0)
print(q0_res)
# Out:
# <rdflib.plugins.sparql.processor.SPARQLResult object at 0x7f0cc3baa5e0>

# %%
import json
results_json = q0_res.serialize(format="json")
resultdict = json.loads(results_json)["results"]["bindings"]
result = resultdict[0]['cdsubjects']['value']
print("Number of distinct subjects : "+str(result))
# Out:
# Number of distinct subjects : 957

# %% [markdown]
# Number of distinct treatments

# %%
import rdflib

g = rdflib.Graph()
g.parse(path_to_files+'OhBOI_RDF.nt')

q11 = """
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX obo: <http://purl.obolibrary.org/obo/> 
  PREFIX snomedct: <http://purl.bioontology.org/ontology/SNOMEDCT/> 
  PREFIX ncit:  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#> 
  PREFIX sio: <http://semanticscience.org/resource/> 
  PREFIX mesh: <http://purl.bioontology.org/ontology/MESH/> 
  PREFIX wp: <http://vocabularies.wikipathways.org/wp#> 
  PREFIX cco: <http://rdf.ebi.ac.uk/terms/chembl#> 
  PREFIX ohboi: <https://w3id.org/ohboi#> 

         SELECT ?number_of_distinct_treatments (count (DISTINCT ?treatments) as ?number_of_distinct_treatments) 
         WHERE {
           # ?treatments a ncit:C28180 .
         }
      """

q11_res = g.query(q11)
print(q11_res)
# Out:
# <rdflib.plugins.sparql.processor.SPARQLResult object at 0x7f4a72cc2f40>

# %%
import json
results_json = q11_res.serialize(format="json")
resultdict = json.loads(results_json)["results"]["bindings"]
result = resultdict[0]['number_of_distinct_treatments']['value']
print("Number of distinct treatments : "+str(result))
# Out:
# Number of distinct treatments : 131

# %% [markdown]
# Second question : Distinct properties

# %%
import rdflib

g = rdflib.Graph()
g.parse(path_to_files+'OhBOI_RDF.nt')

q2 = """
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX obo: <http://purl.obolibrary.org/obo/> 
  PREFIX snomedct: <http://purl.bioontology.org/ontology/SNOMEDCT/> 
  PREFIX ncit:  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#> 
  PREFIX sio: <http://semanticscience.org/resource/> 
  PREFIX mesh: <http://purl.bioontology.org/ontology/MESH/> 
  PREFIX wp: <http://vocabularies.wikipathways.org/wp#> 
  PREFIX cco: <http://rdf.ebi.ac.uk/terms/chembl#> 
  PREFIX ohboi: <https://w3id.org/ohboi#> 
         SELECT DISTINCT ?p 
         WHERE {
           # ?s ?p ?o .
         }
      """

q2_res = g.query(q2)
print(q2_res)
# Out:
# <rdflib.plugins.sparql.processor.SPARQLResult object at 0x7f4a7278a5b0>

# %%
import json
import pandas as pd
df = pd.DataFrame.from_dict(q2_res.bindings)
df
# Out:
#                                                     p
# 0     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1                     https://w3id.org/ohboi#contains
# 2              https://w3id.org/ohboi#hasPrescription
# 3      http://semanticscience.org/resource/SIO_001403
# 4                https://w3id.org/ohboi#hasCommonName
# 5     http://www.w3.org/2000/01/rdf-schema#subClassOf
# 6                    https://w3id.org/ohboi#belongsTo
# 7                      https://w3id.org/ohboi#hasCode
# 8                   https://w3id.org/ohboi#prescribes
# 9                   https://w3id.org/ohboi#prevalence
# 10  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 11                https://w3id.org/ohboi#prescribedIn
# 12                    https://w3id.org/ohboi#presents
# 13     http://www.w3.org/2004/02/skos/core#exactMatch
# 14               https://w3id.org/ohboi#isPresentedIn
# 15         http://rdf.ebi.ac.uk/terms/chembl#chemblId
# 16                      https://w3id.org/ohboi#inDate
# 17                   https://w3id.org/ohboi#hasPAName
# 18                   https://w3id.org/ohboi#hasLength
# 19                http://purl.obolibrary.org/obo/mass
# 20                https://w3id.org/ohboi#hasBrandName
# 21              http://purl.obolibrary.org/obo/smiles
# 22             https://w3id.org/ohboi#hasPathwayLabel
# 23                     https://w3id.org/ohboi#hasName
# 24                   https://w3id.org/ohboi#hasSymbol
# 25  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 26           https://w3id.org/ohboi#hasGeneSymbolCode
# 27                    https://w3id.org/ohboi#symbolOf
# 28  http://rdf.ebi.ac.uk/terms/chembl#atcClassific...
# 29             http://purl.obolibrary.org/obo/formula
# 30      http://semanticscience.org/resource/SIO_00061
# 31  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 32     http://semanticscience.org/resource/SIO_010079
# 33            https://w3id.org/ohboi#hasContinentName
# 34             https://w3id.org/ohboi#hasDiseaseLabel
# 35     http://semanticscience.org/resource/SIO_010078
# 36             https://w3id.org/ohboi#hasBacteriaName
# 37     http://semanticscience.org/resource/SIO_001158
# 38                 https://w3id.org/ohboi#hasCityCode
# 39                 https://w3id.org/ohboi#neutralizes
# 40               https://w3id.org/ohboi#hasPrevalence
# 41      https://w3id.org/ohboi#hasFirstCaseReportedIn
# 42             https://w3id.org/ohboi#isNeutralizedBy

# %% [markdown]
# Distinct subjects and properties and non-distinct subject-property tuple count(checking for duplicates)

# %%
import rdflib

g = rdflib.Graph()
g.parse(path_to_files+'OhBOI_RDF.nt')

q31 = """
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX obo: <http://purl.obolibrary.org/obo/> 
  PREFIX snomedct: <http://purl.bioontology.org/ontology/SNOMEDCT/> 
  PREFIX ncit:  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#> 
  PREFIX sio: <http://semanticscience.org/resource/> 
  PREFIX mesh: <http://purl.bioontology.org/ontology/MESH/> 
  PREFIX wp: <http://vocabularies.wikipathways.org/wp#> 
  PREFIX cco: <http://rdf.ebi.ac.uk/terms/chembl#> 
  PREFIX ohboi: <https://w3id.org/ohboi#> 

         SELECT ?s ?p
         WHERE {
           # ?s ?p ?o .
         }
      """

q31_res = g.query(q31)
print(q31_res)
# Out:
# <rdflib.plugins.sparql.processor.SPARQLResult object at 0x7f0cc2d717f0>

# %%
import rdflib

g = rdflib.Graph()
g.parse(path_to_files+'OhBOI_RDF.nt')

q32 = """
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX obo: <http://purl.obolibrary.org/obo/> 
  PREFIX snomedct: <http://purl.bioontology.org/ontology/SNOMEDCT/> 
  PREFIX ncit:  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#> 
  PREFIX sio: <http://semanticscience.org/resource/> 
  PREFIX mesh: <http://purl.bioontology.org/ontology/MESH/> 
  PREFIX wp: <http://vocabularies.wikipathways.org/wp#> 
  PREFIX cco: <http://rdf.ebi.ac.uk/terms/chembl#> 
  PREFIX ohboi: <https://w3id.org/ohboi#> 

         SELECT DISTINCT ?s ?p 
         WHERE {
           # ?s ?p ?o .
         }
      """

q32_res = g.query(q32)
print(q32_res)
# Out:
# <rdflib.plugins.sparql.processor.SPARQLResult object at 0x7f0cc3ab8100>

# %%
import json
import pandas as pd
df = pd.DataFrame.from_dict(q32_res.bindings)
df_nd = pd.DataFrame.from_dict(q31_res.bindings)
print("Number of distinct subject property tuples: ", df.shape[0])
print("Number of repeated s-p tuples: ", df_nd.shape[0]-df.shape[0] )
print('----------------------')
print("Number of triples: ", df_nd.shape[0])
# Out:
# Number of distinct subject property tuples:  3184
# Number of repeated s-p tuples:  744
# ----------------------
# Number of triples:  3928

# %% [markdown]
# #Competency Questions

# %% [markdown]
# What pathogens exist for Y disease

# %%
import rdflib

g = rdflib.Graph()
g.parse(path_to_files+'OhBOI_RDF.nt')

# paying careful attention to the typo in the property schema:adress 
# that the materialized KG loaded because of a misspelling in the mapping rule declaration

cq1 = """
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX obo: <http://purl.obolibrary.org/obo/> 
  PREFIX snomedct: <http://purl.bioontology.org/ontology/SNOMEDCT/> 
  PREFIX ncit:  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#> 
  PREFIX sio: <http://semanticscience.org/resource/> 
  PREFIX mesh: <http://purl.bioontology.org/ontology/MESH/> 
  PREFIX wp: <http://vocabularies.wikipathways.org/wp#> 
  PREFIX cco: <http://rdf.ebi.ac.uk/terms/chembl#> 
  PREFIX ohboi: <https://w3id.org/ohboi#>  

  SELECT DISTINCT ?Pathogen ?pathogen_NCIT_code ?Disease ?Disease_SNOMED_code 
         WHERE {
           # ?pathogen_XCO_Code rdfs:subClassOf ?pathogen_NCIT_code .
           # ?pathogen_NCIT_code ohboi:hasBacteriaName ?Pathogen .
           # ?pathogen_XCO_Code snomedct:cause_of ?Disease_DOID_code .
           # ?Disease_DOID_code snomedct:due_to ?pathogen_XCO_Code .
           # ?Disease_DOID_code rdfs:subClassOf ?Disease_SNOMED_code .
           # ?Disease_SNOMED_code ohboi:hasDiseaseLabel ?Disease .
         }
      """

cq1_res = g.query(cq1)
print(cq1_res)
# Out:
# <rdflib.plugins.sparql.processor.SPARQLResult object at 0x7f6dca6db3a0>

# %%
import json
import pandas as pd
df_CQ1 = pd.DataFrame.from_dict(cq1_res.bindings)
df_CQ1
# Out:
#                                               Disease  \
# 0                                           Pneumonia
# 1                                 Chronic tonsillitis
# 2   Cholera due to Vibrio cholerae O1 Classical bi...
# 3                              Pulmonary tuberculosis
# 4                Tuberculosis of genitourinary system
# 5                 Tuberculosis of bones and/or joints
# 6                           Disseminated tuberculosis
# 7                    Multidrug resistant tuberculosis
# 8                                     Relapsing fever
# 9                                        Lyme disease
# 10                                          Pneumonia
# 11                                Chronic tonsillitis
# 12                                         Cellulitis
# 13        Chronic gonorrhea lower genitourinary tract
# 14                                        Listeriosis
#
#                                   Disease_SNOMED_code  \
# 0   http://purl.bioontology.org/ontology/SNOMEDCT/...
# 1   http://purl.bioontology.org/ontology/SNOMEDCT/...
# 2   http://purl.bioontology.org/ontology/SNOMEDCT/...
# 3   http://purl.bioontology.org/ontology/SNOMEDCT/...
# 4   http://purl.bioontology.org/ontology/SNOMEDCT/...
# 5   http://purl.bioontology.org/ontology/SNOMEDCT/...
# 6   http://purl.bioontology.org/ontology/SNOMEDCT/...
# 7   http://purl.bioontology.org/ontology/SNOMEDCT/...
# 8   http://purl.bioontology.org/ontology/SNOMEDCT/...
# 9   http://purl.bioontology.org/ontology/SNOMEDCT/...
# 10  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 11  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 12  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 13  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 14  http://purl.bioontology.org/ontology/SNOMEDCT/...
#
#                       Pathogen  \
# 0     Streptococcus pneumoniae
# 1     Streptococcus pneumoniae
# 2    Vibrio cholerae-asiaticae
# 3   Mycobacterium tuberculosis
# 4   Mycobacterium tuberculosis
# 5   Mycobacterium tuberculosis
# 6   Mycobacterium tuberculosis
# 7   Mycobacterium tuberculosis
# 8                     Borrelia
# 9                     Borrelia
# 10       staphylococcus aureus
# 11       staphylococcus aureus
# 12       staphylococcus aureus
# 13                   Neisseria
# 14      Listeria momocytogenes
#
#                                    pathogen_NCIT_code
# 0   http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 1   http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 2   http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 3   http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 4   http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 5   http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 6   http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 7   http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 8   http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 9   http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 10  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 11  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 12  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 13  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 14  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...

# %%
# from a specific disease SNOMED TERM : Lyme Disease -->  http://purl.bioontology.org/ontology/SNOMEDCT/23502006
df_CQ1[df_CQ1[rdflib.term.Variable('Disease_SNOMED_code')]==rdflib.term.URIRef("http://purl.bioontology.org/ontology/SNOMEDCT/23502006")]
# Out:
#         Disease                                Disease_SNOMED_code  Pathogen  \
# 9  Lyme disease  http://purl.bioontology.org/ontology/SNOMEDCT/...  Borrelia
#
#                                   pathogen_NCIT_code
# 9  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...

# %% [markdown]
# Saving example to csv

# %%
df_example.to_csv(path_to_files+"Data_Example.csv", index=False)

# %% [markdown]
# Treatment approved for X infection

# %%
import rdflib

g = rdflib.Graph()
g.parse(path_to_files+'OhBOI_RDF.nt')

# paying careful attention to the typo in the property schema:adress 
# that the materialized KG loaded because of a misspelling in the mapping rule declaration

cq2 = """
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX skos: <http://www.w3.org/2004/02/skos/core#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX obo: <http://purl.obolibrary.org/obo/> 
  PREFIX snomedct: <http://purl.bioontology.org/ontology/SNOMEDCT/> 
  PREFIX ncit:  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#> 
  PREFIX sio: <http://semanticscience.org/resource/> 
  PREFIX mesh: <http://purl.bioontology.org/ontology/MESH/> 
  PREFIX wp: <http://vocabularies.wikipathways.org/wp#> 
  PREFIX cco: <http://rdf.ebi.ac.uk/terms/chembl#> 
  PREFIX ohboi: <https://w3id.org/ohboi#> 

  SELECT DISTINCT ?Disease ?Disease_SNOMED_code ?Drug_ID ?Drug_BrandName ?Drug_CommonName ?Substance ?atc ?mass ?formula ?smiles
         WHERE {
           # ?Disease_DOID_code rdfs:subClassOf ?Disease_SNOMED_code .
           # ?Disease_SNOMED_code ohboi:hasDiseaseLabel ?Disease .
           # ?Disease_DOID_code ohboi:hasPrescription ?Presc .
           # ?Presc ohboi:prescribes ?Drug_ID .
           # ?Drug_ID ohboi:prescribedIn ?Presc .
           OPTIONAL { ?Drug_ID ohboi:hasBrandName ?Drug_BrandName }
           OPTIONAL { ?Drug_ID ohboi:hasCommonName ?Drug_CommonName }
           # ?Drug_ID rdfs:subClassOf ?Substance .
           OPTIONAL { ?Substance cco:atcClassification ?atc }
           # ?Substance skos:exactMatch ?ChemEntity
           OPTIONAL { ?ChemEntity obo:formula ?formula }
           OPTIONAL { ?ChemEntity obo:mass ?mass }
           OPTIONAL { ?ChemEntity obo:smiles ?smiles }
         }
      """

cq2_res = g.query(cq2)
print(cq2_res)
# Out:
# <rdflib.plugins.sparql.processor.SPARQLResult object at 0x7f6dc796b370>

# %%
import json
import pandas as pd
df_CQ2 = pd.DataFrame.from_dict(cq2_res.bindings)
df_CQ2
# Out:
#                                               Disease  \
# 0         Chronic gonorrhea lower genitourinary tract
# 1                                 Chronic tonsillitis
# 2   Cholera due to Vibrio cholerae O1 Classical bi...
# 3                                           Pneumonia
# 4                                 Chronic tonsillitis
# 5                                           Pneumonia
# 6                                          Cellulitis
# 7                                           Pneumonia
# 8                                 Chronic tonsillitis
# 9                                 Chronic tonsillitis
# 10                   Multidrug resistant tuberculosis
# 11                   Multidrug resistant tuberculosis
# 12                                          Pneumonia
# 13                                          Pneumonia
# 14                                          Pneumonia
# 15                                         Cellulitis
# 16                                Chronic tonsillitis
# 17                             Pulmonary tuberculosis
# 18                                    Relapsing fever
# 19                                          Pneumonia
# 20                                          Pneumonia
# 21                                Chronic tonsillitis
# 22                             Pulmonary tuberculosis
# 23  Cholera due to Vibrio cholerae O1 Classical bi...
# 24                             Pulmonary tuberculosis
# 25                                          Pneumonia
# 26                                Chronic tonsillitis
# 27                                       Lyme disease
# 28                                       Lyme disease
# 29                                Chronic tonsillitis
# 30                                          Pneumonia
# 31                                         Cellulitis
# 32        Chronic gonorrhea lower genitourinary tract
# 33                                         Cellulitis
# 34                                          Pneumonia
# 35                          Disseminated tuberculosis
# 36                                          Pneumonia
# 37                                Chronic tonsillitis
# 38  Cholera due to Vibrio cholerae O1 Classical bi...
# 39                                          Pneumonia
# 40                             Pulmonary tuberculosis
# 41                                          Pneumonia
# 42                             Pulmonary tuberculosis
# 43                                Chronic tonsillitis
# 44                                         Cellulitis
# 45                             Pulmonary tuberculosis
# 46                                Chronic tonsillitis
# 47        Chronic gonorrhea lower genitourinary tract
# 48                                          Pneumonia
# 49        Chronic gonorrhea lower genitourinary tract
#
#                                   Disease_SNOMED_code Drug_BrandName  \
# 0   http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 1   http://purl.bioontology.org/ontology/SNOMEDCT/...       Solfoton
# 2   http://purl.bioontology.org/ontology/SNOMEDCT/...       Solfoton
# 3   http://purl.bioontology.org/ontology/SNOMEDCT/...       Solfoton
# 4   http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 5   http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 6   http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 7   http://purl.bioontology.org/ontology/SNOMEDCT/...       Foscavir
# 8   http://purl.bioontology.org/ontology/SNOMEDCT/...      Aminopar
# 9   http://purl.bioontology.org/ontology/SNOMEDCT/...       Foscavir
# 10  http://purl.bioontology.org/ontology/SNOMEDCT/...      Aminopar
# 11  http://purl.bioontology.org/ontology/SNOMEDCT/...       Foscavir
# 12  http://purl.bioontology.org/ontology/SNOMEDCT/...      Aminopar
# 13  http://purl.bioontology.org/ontology/SNOMEDCT/...         Pylera
# 14  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 15  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 16  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 17  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 18  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 19  http://purl.bioontology.org/ontology/SNOMEDCT/...       Mekinist
# 20  http://purl.bioontology.org/ontology/SNOMEDCT/...       Diflucan
# 21  http://purl.bioontology.org/ontology/SNOMEDCT/...       Diflucan
# 22  http://purl.bioontology.org/ontology/SNOMEDCT/...       Diflucan
# 23  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 24  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 25  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 26  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 27  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 28  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 29  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 30  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 31  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 32  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 33  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 34  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 35  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
# 36  http://purl.bioontology.org/ontology/SNOMEDCT/...         Klaron
# 37  http://purl.bioontology.org/ontology/SNOMEDCT/...       Nembutal
# 38  http://purl.bioontology.org/ontology/SNOMEDCT/...       Nembutal
# 39  http://purl.bioontology.org/ontology/SNOMEDCT/...       Nembutal
# 40  http://purl.bioontology.org/ontology/SNOMEDCT/...       Nembutal
# 41  http://purl.bioontology.org/ontology/SNOMEDCT/...        Amoxil
# 42  http://purl.bioontology.org/ontology/SNOMEDCT/...        Amoxil
# 43  http://purl.bioontology.org/ontology/SNOMEDCT/...        Amoxil
# 44  http://purl.bioontology.org/ontology/SNOMEDCT/...         Pylera
# 45  http://purl.bioontology.org/ontology/SNOMEDCT/...         Pylera
# 46  http://purl.bioontology.org/ontology/SNOMEDCT/...         Pylera
# 47  http://purl.bioontology.org/ontology/SNOMEDCT/...        Amoxil
# 48  http://purl.bioontology.org/ontology/SNOMEDCT/...       TAFINLAR
# 49  http://purl.bioontology.org/ontology/SNOMEDCT/...            NaN
#
#       Drug_CommonName                                            Drug_ID  \
# 0         cefpodoxime  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 1       phenobarbital  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 2       phenobarbital  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 3       phenobarbital  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 4   cefuroxime axetil  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 5   cefuroxime axetil  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 6   cefuroxime axetil  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 7           foscarnet  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 8           Aminopar   https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 9           foscarnet  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 10          Aminopar   https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 11          foscarnet  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 12          Aminopar   https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 13      metronidazole  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 14        cefpodoxime  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 15        cefpodoxime  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 16        cefpodoxime  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 17        cefpodoxime  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 18        cefpodoxime  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 19         trametinib  https://pubchem.ncbi.nlm.nih.gov/compound/1117...
# 20        fluconazole  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 21        fluconazole  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 22        fluconazole  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 23            glucose  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 24            glucose  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 25            glucose  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 26            glucose  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 27         cefditoren  https://pubchem.ncbi.nlm.nih.gov/compound/1004...
# 28  cefuroxime axetil  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 29         cefditoren  https://pubchem.ncbi.nlm.nih.gov/compound/1004...
# 30         cefditoren  https://pubchem.ncbi.nlm.nih.gov/compound/1004...
# 31         cefditoren  https://pubchem.ncbi.nlm.nih.gov/compound/1004...
# 32       gatifloxacin  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 33       gatifloxacin  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 34       gatifloxacin  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 35       gatifloxacin  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 36      sulfacetamide  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 37      pentobarbital  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 38      pentobarbital  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 39      pentobarbital  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 40      pentobarbital  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 41        amoxicillin  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 42        amoxicillin  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 43        amoxicillin  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 44      metronidazole  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 45      metronidazole  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 46      metronidazole  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 47        amoxicillin  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
# 48         dabrafenib  https://pubchem.ncbi.nlm.nih.gov/compound/1444...
# 49  cefuroxime axetil  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
#
#                                             Substance              atc  \
# 0   https://www.ebi.ac.uk/chembl/compound_report_c...          J01DD13
# 1   https://www.ebi.ac.uk/chembl/compound_report_c...          N03AA02
# 2   https://www.ebi.ac.uk/chembl/compound_report_c...          N03AA02
# 3   https://www.ebi.ac.uk/chembl/compound_report_c...          N03AA02
# 4   https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 5   https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 6   https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 7   https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 8   https://www.ebi.ac.uk/chembl/compound_report_c...          J04AA01
# 9   https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 10  https://www.ebi.ac.uk/chembl/compound_report_c...          J04AA01
# 11  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 12  https://www.ebi.ac.uk/chembl/compound_report_c...          J04AA01
# 13  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 14  https://www.ebi.ac.uk/chembl/compound_report_c...          J01DD13
# 15  https://www.ebi.ac.uk/chembl/compound_report_c...          J01DD13
# 16  https://www.ebi.ac.uk/chembl/compound_report_c...          J01DD13
# 17  https://www.ebi.ac.uk/chembl/compound_report_c...          J01DD13
# 18  https://www.ebi.ac.uk/chembl/compound_report_c...          J01DD13
# 19  https://www.ebi.ac.uk/chembl/compound_report_c...          L01EE01
# 20  https://www.ebi.ac.uk/chembl/compound_report_c...  J02AC01_D01AC15
# 21  https://www.ebi.ac.uk/chembl/compound_report_c...  J02AC01_D01AC15
# 22  https://www.ebi.ac.uk/chembl/compound_report_c...  J02AC01_D01AC15
# 23  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 24  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 25  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 26  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 27  https://www.ebi.ac.uk/chembl/compound_report_c...          J01DD16
# 28  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 29  https://www.ebi.ac.uk/chembl/compound_report_c...          J01DD16
# 30  https://www.ebi.ac.uk/chembl/compound_report_c...          J01DD16
# 31  https://www.ebi.ac.uk/chembl/compound_report_c...          J01DD16
# 32  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 33  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 34  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 35  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 36  https://www.ebi.ac.uk/chembl/compound_report_c...  S01AB04_D10AF06
# 37  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 38  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 39  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 40  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 41  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 42  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 43  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 44  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 45  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 46  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 47  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
# 48  https://www.ebi.ac.uk/chembl/compound_report_c...          L01EC02
# 49  https://www.ebi.ac.uk/chembl/compound_report_c...              NaN
#
#            formula    mass                                             smiles
# 0     C15H17N5O6S2  427.46  COCC1=C(N2C(C(C2=O)NC(=O)C(=NOC)C3=CSC(=N3)N)S...
# 1       C12H12N2O3  232.24                  CCC1(C(=O)NC(=O)NC1=O)C2=CC=CC=C2
# 2       C12H12N2O3  232.24                  CCC1(C(=O)NC(=O)NC1=O)C2=CC=CC=C2
# 3       C12H12N2O3  232.24                  CCC1(C(=O)NC(=O)NC1=O)C2=CC=CC=C2
# 4     C20H22N4O10S  510.48  CC(OC(=O)C)OC(=O)C1=C(CSC2N1C(=O)C2NC(=O)C(=NO...
# 5     C20H22N4O10S  510.48  CC(OC(=O)C)OC(=O)C1=C(CSC2N1C(=O)C2NC(=O)C(=NO...
# 6     C20H22N4O10S  510.48  CC(OC(=O)C)OC(=O)C1=C(CSC2N1C(=O)C2NC(=O)C(=NO...
# 7          CNa3O5P  191.95                                  C(=O)(O)P(=O)(O)O
# 8          C7H7NO3  153.14                            C1=CC(=C(C=C1N)O)C(=O)O
# 9          CNa3O5P  191.95                                  C(=O)(O)P(=O)(O)O
# 10         C7H7NO3  153.14                            C1=CC(=C(C=C1N)O)C(=O)O
# 11         CNa3O5P  191.95                                  C(=O)(O)P(=O)(O)O
# 12         C7H7NO3  153.14                            C1=CC(=C(C=C1N)O)C(=O)O
# 13     C6H10ClN3O3  207.62                        CC1=NC=C(N1CCO)[N+](=O)[O-]
# 14    C15H17N5O6S2  427.46  COCC1=C(N2C(C(C2=O)NC(=O)C(=NOC)C3=CSC(=N3)N)S...
# 15    C15H17N5O6S2  427.46  COCC1=C(N2C(C(C2=O)NC(=O)C(=NOC)C3=CSC(=N3)N)S...
# 16    C15H17N5O6S2  427.46  COCC1=C(N2C(C(C2=O)NC(=O)C(=NOC)C3=CSC(=N3)N)S...
# 17    C15H17N5O6S2  427.46  COCC1=C(N2C(C(C2=O)NC(=O)C(=NOC)C3=CSC(=N3)N)S...
# 18    C15H17N5O6S2  427.46  COCC1=C(N2C(C(C2=O)NC(=O)C(=NOC)C3=CSC(=N3)N)S...
# 19    C26H23FIN5O4   615.4  CC1=C2C(=C(N(C1=O)C)NC3=C(C=C(C=C3)I)F)C(=O)N(...
# 20     C13H12F2N6O  306.28        C1=CC(=C(C=C1F)F)C(CN2C=NC=N2)(CN3C=NC=N3)O
# 21     C13H12F2N6O  306.28        C1=CC(=C(C=C1F)F)C(CN2C=NC=N2)(CN3C=NC=N3)O
# 22     C13H12F2N6O  306.28        C1=CC(=C(C=C1F)F)C(CN2C=NC=N2)(CN3C=NC=N3)O
# 23         C6H12O6  180.16                           C(C1C(C(C(C(O1)O)O)O)O)O
# 24         C6H12O6  180.16                           C(C1C(C(C(C(O1)O)O)O)O)O
# 25         C6H12O6  180.16                           C(C1C(C(C(C(O1)O)O)O)O)O
# 26         C6H12O6  180.16                           C(C1C(C(C(C(O1)O)O)O)O)O
# 27    C19H18N6O5S3  506.59  CC1=C(SC=N1)C=CC2=C(N3C(C(C3=O)NC(=O)C(=NOC)C4...
# 28    C20H22N4O10S  510.48  CC(OC(=O)C)OC(=O)C1=C(CSC2N1C(=O)C2NC(=O)C(=NO...
# 29    C19H18N6O5S3  506.59  CC1=C(SC=N1)C=CC2=C(N3C(C(C3=O)NC(=O)C(=NOC)C4...
# 30    C19H18N6O5S3  506.59  CC1=C(SC=N1)C=CC2=C(N3C(C(C3=O)NC(=O)C(=NOC)C4...
# 31    C19H18N6O5S3  506.59  CC1=C(SC=N1)C=CC2=C(N3C(C(C3=O)NC(=O)C(=NOC)C4...
# 32     C19H22FN3O4   375.4  CC1CN(CCN1)C2=C(C=C3C(=C2OC)N(C=C(C3=O)C(=O)O)...
# 33     C19H22FN3O4   375.4  CC1CN(CCN1)C2=C(C=C3C(=C2OC)N(C=C(C3=O)C(=O)O)...
# 34     C19H22FN3O4   375.4  CC1CN(CCN1)C2=C(C=C3C(=C2OC)N(C=C(C3=O)C(=O)O)...
# 35     C19H22FN3O4   375.4  CC1CN(CCN1)C2=C(C=C3C(=C2OC)N(C=C(C3=O)C(=O)O)...
# 36      C8H10N2O3S  214.25                     CC(=O)NS(=O)(=O)C1=CC=C(C=C1)N
# 37    C11H17N2NaO3  248.26                      CCCC(C)C1(C(=O)NC(=O)NC1=O)CC
# 38    C11H17N2NaO3  248.26                      CCCC(C)C1(C(=O)NC(=O)NC1=O)CC
# 39    C11H17N2NaO3  248.26                      CCCC(C)C1(C(=O)NC(=O)NC1=O)CC
# 40    C11H17N2NaO3  248.26                      CCCC(C)C1(C(=O)NC(=O)NC1=O)CC
# 41   C16H18N3NaO5S  387.39  CC1(C(N2C(S1)C(C2=O)NC(=O)C(C3=CC=C(C=C3)O)N)C...
# 42   C16H18N3NaO5S  387.39  CC1(C(N2C(S1)C(C2=O)NC(=O)C(C3=CC=C(C=C3)O)N)C...
# 43   C16H18N3NaO5S  387.39  CC1(C(N2C(S1)C(C2=O)NC(=O)C(C3=CC=C(C=C3)O)N)C...
# 44     C6H10ClN3O3  207.62                        CC1=NC=C(N1CCO)[N+](=O)[O-]
# 45     C6H10ClN3O3  207.62                        CC1=NC=C(N1CCO)[N+](=O)[O-]
# 46     C6H10ClN3O3  207.62                        CC1=NC=C(N1CCO)[N+](=O)[O-]
# 47   C16H18N3NaO5S  387.39  CC1(C(N2C(S1)C(C2=O)NC(=O)C(C3=CC=C(C=C3)O)N)C...
# 48  C23H20F3N5O2S2  519.57  CC(C)(C)C1=NC(=C(S1)C2=NC(=NC=C2)N)C3=C(C(=CC=...
# 49    C20H22N4O10S  510.48  CC(OC(=O)C)OC(=O)C1=C(CSC2N1C(=O)C2NC(=O)C(=NO...

# %%
# from a specific disease SNOMED TERM : Lyme Disease -->  http://purl.bioontology.org/ontology/SNOMEDCT/23502006
df_CQ2[df_CQ2[rdflib.term.Variable('Disease_SNOMED_code')]==rdflib.term.URIRef("http://purl.bioontology.org/ontology/SNOMEDCT/23502006")]
# Out:
#          Disease                                Disease_SNOMED_code  \
# 27  Lyme disease  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 28  Lyme disease  http://purl.bioontology.org/ontology/SNOMEDCT/...
#
#    Drug_BrandName    Drug_CommonName  \
# 27            NaN         cefditoren
# 28            NaN  cefuroxime axetil
#
#                                               Drug_ID  \
# 27  https://pubchem.ncbi.nlm.nih.gov/compound/1004...
# 28  https://pubchem.ncbi.nlm.nih.gov/compound/1000...
#
#                                             Substance      atc       formula  \
# 27  https://www.ebi.ac.uk/chembl/compound_report_c...  J01DD16  C19H18N6O5S3
# 28  https://www.ebi.ac.uk/chembl/compound_report_c...      NaN  C20H22N4O10S
#
#       mass                                             smiles
# 27  506.59  CC1=C(SC=N1)C=CC2=C(N3C(C(C3=O)NC(=O)C(=NOC)C4...
# 28  510.48  CC(OC(=O)C)OC(=O)C1=C(CSC2N1C(=O)C2NC(=O)C(=NO...

# %% [markdown]
# Antitoxin for a bacterial toxin

# %%
import rdflib

g = rdflib.Graph()
g.parse(path_to_files+'OhBOI_RDF.nt')

# paying careful attention to the typo in the property schema:adress 
# that the materialized KG loaded because of a misspelling in the mapping rule declaration

cq3 = """
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX obo: <http://purl.obolibrary.org/obo/> 
  PREFIX snomedct: <http://purl.bioontology.org/ontology/SNOMEDCT/> 
  PREFIX ncit:  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#> 
  PREFIX sio: <http://semanticscience.org/resource/> 
  PREFIX mesh: <http://purl.bioontology.org/ontology/MESH/> 
  PREFIX wp: <http://vocabularies.wikipathways.org/wp#> 
  PREFIX cco: <http://rdf.ebi.ac.uk/terms/chembl#> 
  PREFIX ohboi: <https://w3id.org/ohboi#> 

  SELECT DISTINCT ?Pathogen ?pathogen_NCIT_code ?gene_symbol ?Toxin ?toxin_name ?number_aminoacids ?Antitoxin ?Drug_Term_Antitoxin
         WHERE {
           # ?pathogen_NCIT_code ohboi:hasBacteriaName ?Pathogen .
           # ?pathogen_NCIT_code ncit:R41 ?gene .
           OPTIONAL{ ?gene ohboi:hasSymbol ?gs} 
           OPTIONAL{ ?gs ohboi:hasGeneSymbolCode ?gene_symbol} 
           # ?protein sio:SIO_010079 ?gene .
           OPTIONAL{ ?protein ohboi:hasLength ?number_aminoacids} 
           OPTIONAL{ ?protein ohboi:hasName ?toxin_name} 
           # ?proteinToxin rdfs:subClassOf ?Toxin .
           # ?Toxin ohboi:isNeutralizedBy ?Antitoxin .
           OPTIONAL{ ?Antitoxin rdfs:subClassOf ?Drug_Term_Antitoxin}
         }
      """

cq3_res = g.query(cq3)
print(cq3_res)
# Out:
# <rdflib.plugins.sparql.processor.SPARQLResult object at 0x7f6dc8723ca0>

# %%
import json
import pandas as pd
df_CQ3 = pd.DataFrame.from_dict(cq3_res.bindings)
df_CQ3.head()
# Out:
#                                            Antitoxin  \
# 0  https://pubchem.ncbi.nlm.nih.gov/substance/160...
# 1  https://pubchem.ncbi.nlm.nih.gov/substance/160...
# 2  https://pubchem.ncbi.nlm.nih.gov/substance/160...
# 3  https://pubchem.ncbi.nlm.nih.gov/substance/160...
# 4  https://pubchem.ncbi.nlm.nih.gov/substance/160...
#
#                                  Drug_Term_Antitoxin  \
# 0  https://www.ebi.ac.uk/chembl/compound_report_c...
# 1  https://pubchem.ncbi.nlm.nih.gov/substance/160...
# 2  https://www.ebi.ac.uk/chembl/compound_report_c...
# 3  https://pubchem.ncbi.nlm.nih.gov/substance/160...
# 4  https://www.ebi.ac.uk/chembl/compound_report_c...
#
#                           Pathogen                                   Toxin  \
# 0         Streptococcus pneumoniae  http://purl.uniprot.org/uniprot/P0DPI1
# 1         Streptococcus pneumoniae  http://purl.uniprot.org/uniprot/P0DPI1
# 2            staphylococcus aureus  http://purl.uniprot.org/uniprot/P0DPI1
# 3            staphylococcus aureus  http://purl.uniprot.org/uniprot/P0DPI1
# 4  VPI 4440 Clostridium putrificum  http://purl.uniprot.org/uniprot/P0DPI1
#
#    gene_symbol number_aminoacids  \
# 0         purB               432
# 1         purB               432
# 2         floA               329
# 3         floA               329
# 4  FDG75_00035               206
#
#                                   pathogen_NCIT_code  \
# 0  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 1  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 2  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 3  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 4  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
#
#                     toxin_name
# 0       Adenylosuccinate lyase
# 1       Adenylosuccinate lyase
# 2  Flotillin-like protein FloA
# 3  Flotillin-like protein FloA
# 4        Antitoxin botulinum a

# %%
# from a specific microbial Taxon - Clostridium Botulinum NCBI-TAXON ID 1491 -->  VPI 4440 Clostridium putrificum

columnslist=[rdflib.term.Variable('Pathogen'), rdflib.term.Variable('pathogen_NCIT_code'),  rdflib.term.Variable('Drug_Term_Antitoxin'), rdflib.term.Variable('Toxin'), rdflib.term.Variable('toxin_name'), rdflib.term.Variable('gene_symbol'), rdflib.term.Variable('number_aminoacids') ]
df_CQ3[df_CQ3[rdflib.term.Variable('Pathogen')]==rdflib.term.Literal('VPI 4440 Clostridium putrificum')][columnslist]
# Out:
#                            Pathogen  \
# 4   VPI 4440 Clostridium putrificum
# 5   VPI 4440 Clostridium putrificum
# 26  VPI 4440 Clostridium putrificum
# 27  VPI 4440 Clostridium putrificum
#
#                                    pathogen_NCIT_code  \
# 4   http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 5   http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 26  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 27  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
#
#                                   Drug_Term_Antitoxin  \
# 4   https://www.ebi.ac.uk/chembl/compound_report_c...
# 5   https://pubchem.ncbi.nlm.nih.gov/substance/160...
# 26  https://www.ebi.ac.uk/chembl/compound_report_c...
# 27  https://pubchem.ncbi.nlm.nih.gov/substance/160...
#
#                                      Toxin                   toxin_name  \
# 4   http://purl.uniprot.org/uniprot/P0DPI1        Antitoxin botulinum a
# 5   http://purl.uniprot.org/uniprot/P0DPI1        Antitoxin botulinum a
# 26  http://purl.uniprot.org/uniprot/P0DPI1  Botulinum neurotoxin type A
# 27  http://purl.uniprot.org/uniprot/P0DPI1  Botulinum neurotoxin type A
#
#     gene_symbol number_aminoacids
# 4   FDG75_00035               206
# 5   FDG75_00035               206
# 26         bont              1296
# 27         bont              1296

# %% [markdown]
# Symptoms associated to a disease

# %%
import rdflib

g = rdflib.Graph()
g.parse(path_to_files+'OhBOI_RDF.nt')

# paying careful attention to the typo in the property schema:adress 
# that the materialized KG loaded because of a misspelling in the mapping rule declaration

cq4 = """
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX obo: <http://purl.obolibrary.org/obo/> 
  PREFIX snomedct: <http://purl.bioontology.org/ontology/SNOMEDCT/> 
  PREFIX ncit:  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#> 
  PREFIX sio: <http://semanticscience.org/resource/> 
  PREFIX mesh: <http://purl.bioontology.org/ontology/MESH/> 
  PREFIX wp: <http://vocabularies.wikipathways.org/wp#> 
  PREFIX cco: <http://rdf.ebi.ac.uk/terms/chembl#> 
  PREFIX ohboi: <https://w3id.org/ohboi#> 
  SELECT DISTINCT ?Disease ?Disease_SNOMED_code ?Symptom_code ?Symptom
         WHERE {
           # ?Disease_DOID_code rdfs:subClassOf ?Disease_SNOMED_code .
           # ?Disease_SNOMED_code ohboi:hasDiseaseLabel ?Disease .
           # ?Disease_DOID_code ohboi:presents ?Symptom_code .
           # ?Symptom_code ohboi:hasPAName ?Symptom
         }
      """

cq4_res = g.query(cq4)
print(cq4_res)
# Out:
# <rdflib.plugins.sparql.processor.SPARQLResult object at 0x7f6dc77841f0>

# %%
import json
import pandas as pd
df_CQ4 = pd.DataFrame.from_dict(cq4_res.bindings)
df_CQ4
# Out:
#                                                Disease  \
# 0                                         Lyme disease
# 1                                         Lyme disease
# 2                                         Lyme disease
# 3                                         Lyme disease
# 4                                         Lyme disease
# ..                                                 ...
# 169  Cholera due to Vibrio cholerae O1 Classical bi...
# 170  Cholera due to Vibrio cholerae O1 Classical bi...
# 171  Cholera due to Vibrio cholerae O1 Classical bi...
# 172  Cholera due to Vibrio cholerae O1 Classical bi...
# 173  Cholera due to Vibrio cholerae O1 Classical bi...
#
#                                    Disease_SNOMED_code  \
# 0    http://purl.bioontology.org/ontology/SNOMEDCT/...
# 1    http://purl.bioontology.org/ontology/SNOMEDCT/...
# 2    http://purl.bioontology.org/ontology/SNOMEDCT/...
# 3    http://purl.bioontology.org/ontology/SNOMEDCT/...
# 4    http://purl.bioontology.org/ontology/SNOMEDCT/...
# ..                                                 ...
# 169  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 170  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 171  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 172  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 173  http://purl.bioontology.org/ontology/SNOMEDCT/...
#
#                                    Symptom  \
# 0         Decreased facial muscle strength
# 1          Abnormality of the facial nerve
# 2                          CSF pleocytosis
# 3                             Bell's palsy
# 4               Erythema chronicum migrans
# ..                                     ...
# 169  Non-occlusive coronary artery disease
# 170                decreased itch response
# 171                  increased thigmotaxis
# 172      decreased mast cell degranulation
# 173          decreased synaptic depression
#
#                                   Symptom_code
# 0    http://purl.obolibrary.org/obo/HP_0030319
# 1    http://purl.obolibrary.org/obo/HP_0010827
# 2    http://purl.obolibrary.org/obo/HP_0012229
# 3    http://purl.obolibrary.org/obo/HP_0010628
# 4    http://purl.obolibrary.org/obo/HP_0031180
# ..                                         ...
# 169  http://purl.obolibrary.org/obo/HP_0012436
# 170  http://purl.obolibrary.org/obo/MP_0010073
# 171  http://purl.obolibrary.org/obo/MP_0002797
# 172  http://purl.obolibrary.org/obo/MP_0008765
# 173  http://purl.obolibrary.org/obo/MP_0002917
#
# [174 rows x 4 columns]

# %%
# from a specific disease SNOMED TERM : Lyme Disease -->  http://purl.bioontology.org/ontology/SNOMEDCT/23502006
df_CQ4[df_CQ4[rdflib.term.Variable('Disease_SNOMED_code')]==rdflib.term.URIRef("http://purl.bioontology.org/ontology/SNOMEDCT/23502006")]
# Out:
#          Disease                                Disease_SNOMED_code  \
# 0   Lyme disease  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 1   Lyme disease  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 2   Lyme disease  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 3   Lyme disease  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 4   Lyme disease  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 5   Lyme disease  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 6   Lyme disease  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 7   Lyme disease  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 8   Lyme disease  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 9   Lyme disease  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 10  Lyme disease  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 11  Lyme disease  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 12  Lyme disease  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 13  Lyme disease  http://purl.bioontology.org/ontology/SNOMEDCT/...
# 14  Lyme disease  http://purl.bioontology.org/ontology/SNOMEDCT/...
#
#                                  Symptom  \
# 0       Decreased facial muscle strength
# 1        Abnormality of the facial nerve
# 2                        CSF pleocytosis
# 3                           Bell's palsy
# 4             Erythema chronicum migrans
# 5   abnormal visual contrast sensitivity
# 6                               Erythema
# 7                                  Fever
# 8                     Lymphocytoma cutis
# 9                               Headache
# 10                               Fatigue
# 11         Episodic difficulty breathing
# 12        Chronic lymphocytic meningitis
# 13     Bilateral facial muscle paralysis
# 14                 Cranial nerve palsies
#
#                                  Symptom_code
# 0   http://purl.obolibrary.org/obo/HP_0030319
# 1   http://purl.obolibrary.org/obo/HP_0010827
# 2   http://purl.obolibrary.org/obo/HP_0012229
# 3   http://purl.obolibrary.org/obo/HP_0010628
# 4   http://purl.obolibrary.org/obo/HP_0031180
# 5   http://purl.obolibrary.org/obo/MP_0011831
# 6   http://purl.obolibrary.org/obo/HP_0010783
# 7   http://purl.obolibrary.org/obo/HP_0001945
# 8   http://purl.obolibrary.org/obo/HP_0031549
# 9   http://purl.obolibrary.org/obo/HP_0002315
# 10  http://purl.obolibrary.org/obo/HP_0012378
# 11  http://purl.obolibrary.org/obo/HP_0004885
# 12  http://purl.obolibrary.org/obo/HP_0007041
# 13  http://purl.obolibrary.org/obo/HP_0430025
# 14  http://purl.obolibrary.org/obo/HP_0006824

# %% [markdown]
# Prevalence of disease

# %%
import rdflib

g = rdflib.Graph()
g.parse(path_to_files+'OhBOI_RDF.nt')

# paying careful attention to the typo in the property schema:adress 
# that the materialized KG loaded because of a misspelling in the mapping rule declaration

cq5 = """
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX obo: <http://purl.obolibrary.org/obo/> 
  PREFIX snomedct: <http://purl.bioontology.org/ontology/SNOMEDCT/> 
  PREFIX ncit:  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#> 
  PREFIX sio: <http://semanticscience.org/resource/> 
  PREFIX mesh: <http://purl.bioontology.org/ontology/MESH/> 
  PREFIX wp: <http://vocabularies.wikipathways.org/wp#> 
  PREFIX cco: <http://rdf.ebi.ac.uk/terms/chembl#> 
  PREFIX ohboi: <https://w3id.org/ohboi#> 
  SELECT DISTINCT ?Disease ?Disease_SNOMED_code ?Prevalence ?Date ?Country ?NameCity
  WHERE {
           # ?Disease_DOID_code rdfs:subClassOf ?Disease_SNOMED_code .
           # ?Disease_SNOMED_code ohboi:hasDiseaseLabel ?Disease .
           # ?P_ID ohboi:inDate ?Date .
           # ?P_ID ohboi:prevalence ?Prevalence .
           # ?P_ID sio:SIO_001403 ?C_ID .
           # ?C_ID ohboi:hasCode ?Country .
           OPTIONAL{ ?C_ID ohboi:contains ?City .
            # ?City ohboi:hasCityCode ?NameCity }
         }
      """

cq5_res = g.query(cq5)
print(cq5_res)
# Out:
# <rdflib.plugins.sparql.processor.SPARQLResult object at 0x7f6dc7f0c340>

# %%
import json
import pandas as pd
df_CQ5 = pd.DataFrame.from_dict(cq5_res.bindings)
df_CQ5
# Out:
#                                  Country        Date  \
# 0                              Guatemala  01/01/2000
# 1                              Guatemala  01/01/2000
# 2                              Guatemala  01/01/2000
# 3                              Guatemala  01/01/2000
# 4                              Guatemala  01/01/2000
# ...                                  ...         ...
# 3362  Venezuela (Bolivarian Republic of)  01/01/2000
# 3363  Venezuela (Bolivarian Republic of)  01/01/2000
# 3364  Venezuela (Bolivarian Republic of)  01/01/2000
# 3365  Venezuela (Bolivarian Republic of)  01/01/2000
# 3366  Venezuela (Bolivarian Republic of)  01/01/2000
#
#                                                 Disease  \
# 0                                          Lyme disease
# 1                             Disseminated tuberculosis
# 2                                            Cellulitis
# 3                                             Pneumonia
# 4                                           Listeriosis
# ...                                                 ...
# 3362                             Pulmonary tuberculosis
# 3363                                    Relapsing fever
# 3364                   Multidrug resistant tuberculosis
# 3365                Tuberculosis of bones and/or joints
# 3366  Cholera due to Vibrio cholerae O1 Classical bi...
#
#                                     Disease_SNOMED_code NameCity Prevalence
# 0     http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN      0.041
# 1     http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN      0.041
# 2     http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN      0.041
# 3     http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN      0.041
# 4     http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN      0.041
# ...                                                 ...      ...        ...
# 3362  http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN       0.04
# 3363  http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN       0.04
# 3364  http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN       0.04
# 3365  http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN       0.04
# 3366  http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN       0.04
#
# [3367 rows x 6 columns]

# %%
# from a specific disease SNOMED TERM : Pulmonary Tuberculosis -->  http://purl.bioontology.org/ontology/SNOMEDCT/154283005
df_CQ5[df_CQ5[rdflib.term.Variable('Disease_SNOMED_code')]==rdflib.term.URIRef("http://purl.bioontology.org/ontology/SNOMEDCT/154283005")]
# Out:
#                                  Country        Date                 Disease  \
# 8                              Guatemala  01/01/2000  Pulmonary tuberculosis
# 21                             Guatemala  01/01/2021  Pulmonary tuberculosis
# 34                              Kiribati  01/01/2000  Pulmonary tuberculosis
# 47                              Kiribati  01/01/2002  Pulmonary tuberculosis
# 60                           New Zealand  01/01/2008  Pulmonary tuberculosis
# ...                                  ...         ...                     ...
# 3310                               Palau  01/01/2018  Pulmonary tuberculosis
# 3323                Syrian Arab Republic  01/01/2000  Pulmonary tuberculosis
# 3336                              Angola  01/01/2000  Pulmonary tuberculosis
# 3349                             Algeria  01/01/2008  Pulmonary tuberculosis
# 3362  Venezuela (Bolivarian Republic of)  01/01/2000  Pulmonary tuberculosis
#
#                                     Disease_SNOMED_code NameCity Prevalence
# 8     http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN      0.041
# 21    http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN      0.035
# 34    http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN      0.457
# 47    http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN      0.328
# 60    http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN     0.0091
# ...                                                 ...      ...        ...
# 3310  http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN      0.126
# 3323  http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN      0.061
# 3336  http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN      0.404
# 3349  http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN      0.098
# 3362  http://purl.bioontology.org/ontology/SNOMEDCT/...      NaN       0.04
#
# [259 rows x 6 columns]

# %% [markdown]
# First Case Reported

# %%
import rdflib

g = rdflib.Graph()
g.parse(path_to_files+'OhBOI_RDF.nt')

# paying careful attention to the typo in the property schema:adress 
# that the materialized KG loaded because of a misspelling in the mapping rule declaration

cq6 = """
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX obo: <http://purl.obolibrary.org/obo/> 
  PREFIX snomedct: <http://purl.bioontology.org/ontology/SNOMEDCT/> 
  PREFIX ncit:  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#> 
  PREFIX sio: <http://semanticscience.org/resource/> 
  PREFIX mesh: <http://purl.bioontology.org/ontology/MESH/> 
  PREFIX wp: <http://vocabularies.wikipathways.org/wp#> 
  PREFIX cco: <http://rdf.ebi.ac.uk/terms/chembl#> 
  PREFIX ohboi: <https://w3id.org/ohboi#> 

  SELECT DISTINCT ?Disease ?Disease_SNOMED_code ?NameCity
         WHERE {
          # ?Disease_DOID_code rdfs:subClassOf ?Disease_SNOMED_code .
          # ?Disease_SNOMED_code ohboi:hasDiseaseLabel ?Disease .
          # ?Disease_DOID_code ohboi:hasFirstCaseReportedIn ?City .
          # ?City ohboi:hasCityCode ?NameCity
         }
      """

cq6_res = g.query(cq6)
print(cq6_res)
# Out:
# <rdflib.plugins.sparql.processor.SPARQLResult object at 0x7f4a71ab5970>

# %%
import json
import pandas as pd
df_CQ6 = pd.DataFrame.from_dict(cq6_res.bindings)
df_CQ6
# Out:
#                   Disease                                Disease_SNOMED_code  \
# 0  Pulmonary tuberculosis  http://purl.bioontology.org/ontology/SNOMEDCT/...
#
#   NameCity
# 0   Monaco

# %% [markdown]
# Pathways affected by organism and disease

# %%
import rdflib

g = rdflib.Graph()
g.parse(path_to_files+'OhBOI_RDF.nt')

# paying careful attention to the typo in the property schema:adress 
# that the materialized KG loaded because of a misspelling in the mapping rule declaration

cq7 = """
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX schema: <http://schema.org/> 
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
  PREFIX obo: <http://purl.obolibrary.org/obo/> 
  PREFIX snomedct: <http://purl.bioontology.org/ontology/SNOMEDCT/> 
  PREFIX ncit:  <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#> 
  PREFIX sio: <http://semanticscience.org/resource/> 
  PREFIX mesh: <http://purl.bioontology.org/ontology/MESH/> 
  PREFIX wp: <http://vocabularies.wikipathways.org/wp#> 
  PREFIX cco: <http://rdf.ebi.ac.uk/terms/chembl#> 
  PREFIX ohboi: <https://w3id.org/ohboi#> 

  SELECT DISTINCT ?Disease ?Pathogen ?PathwayAffected_ReactomeCode
         WHERE {
           # ?Disease_DOID_code rdfs:subClassOf ?Disease_SNOMED_code .
           # ?Disease_SNOMED_code ohboi:hasDiseaseLabel ?Disease .
           # ?pathogen_XCO_Code rdfs:subClassOf ?pathogen_NCIT_code .
           # ?pathogen_NCIT_code ohboi:hasBacteriaName ?Pathogen .
           # ?pathogen_XCO_Code snomedct:cause_of ?Disease_DOID_code .
           # ?Disease_DOID_code snomedct:due_to ?pathogen_XCO_Code .
           # ?Disease_DOID_code sio:SIO_001158 ?Pathway_ID .
           # ?Pathway_ID ohboi:hasPathwayLabel ?PathwayAffected_ReactomeCode .
         }
      """

cq7_res = g.query(cq7)
print(cq7_res)
# Out:
# <rdflib.plugins.sparql.processor.SPARQLResult object at 0x7f6dca676bb0>

# %%
import json
import pandas as pd
df_CQ7 = pd.DataFrame.from_dict(cq7_res.bindings)
df_CQ7
# Out:
#                                 Disease                    Pathogen  \
# 0             Disseminated tuberculosis  Mycobacterium tuberculosis
# 1                Pulmonary tuberculosis  Mycobacterium tuberculosis
# 2      Multidrug resistant tuberculosis  Mycobacterium tuberculosis
# 3  Tuberculosis of genitourinary system  Mycobacterium tuberculosis
# 4   Tuberculosis of bones and/or joints  Mycobacterium tuberculosis
#
#   PathwayAffected_ReactomeCode
# 0              R-HSA-9637698.1
# 1              R-HSA-9637698.1
# 2              R-HSA-9637698.1
# 3              R-HSA-9637698.1
# 4              R-HSA-9637698.1
